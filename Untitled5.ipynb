# %%
# python standard libraries
import pandas as pd
import numpy as np
import os
import random
import fnmatch
import datetime
import pickle
np.set_printoptions(formatter={'float_kind':lambda x: "%.4f" % x})

# %%
import cv2
from imgaug import augmenters as img_aug
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from PIL import Image

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet import ResNet50
from keras.callbacks import History
history = History()

# %%
# import images
# !cd /content
data_dir1 = '/content/drive/MyDrive/Colab Notebooks/data3_value/frames/'
file_list1 = os.listdir(data_dir1)
image_paths = []
steering_angles = []
pattern = "*.jpg"

# %%
for filename in file_list1:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(data_dir1,filename))
        angle = int(float(filename[-8:-4]))
        steering_angles.append(angle)

# %%
image_index = 10
plt.imshow(Image.open(image_paths[image_index]))
print("image_path: %s" % image_paths[image_index] )
print("steering_Angle: %d" % steering_angles[image_index] )
df = pd.DataFrame()
df['ImagePath'] = image_paths
df['Angle'] = steering_angles
# Out:
# image_path: /content/drive/MyDrive/Colab Notebooks/data3_value/frames/frame_162_6432.jpg
# steering_Angle: 6432

# %%
df.tail(20)
# Out:
#                                               ImagePath  Angle
# 2179  /content/drive/MyDrive/Colab Notebooks/data3_v...   3152
# 2180  /content/drive/MyDrive/Colab Notebooks/data3_v...   6432
# 2181  /content/drive/MyDrive/Colab Notebooks/data3_v...   6432
# 2182  /content/drive/MyDrive/Colab Notebooks/data3_v...   4560
# 2183  /content/drive/MyDrive/Colab Notebooks/data3_v...   4560
# 2184  /content/drive/MyDrive/Colab Notebooks/data3_v...   4560
# 2185  /content/drive/MyDrive/Colab Notebooks/data3_v...   4560
# 2186  /content/drive/MyDrive/Colab Notebooks/data3_v...   6432
# 2187  /content/drive/MyDrive/Colab Notebooks/data3_v...   4560
# 2188  /content/drive/MyDrive/Colab Notebooks/data3_v...   3152
# 2189  /content/drive/MyDrive/Colab Notebooks/data3_v...   4560
# 2190  /content/drive/MyDrive/Colab Notebooks/data3_v...   6432
# 2191  /content/drive/MyDrive/Colab Notebooks/data3_v...   4560
# 2192  /content/drive/MyDrive/Colab Notebooks/data3_v...   3152
# ...

# %%
df_csv = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data3_value/record.csv')

# %%
df_csv
# Out:
#       index  steering  throttle_left  throttle_right  \
# 0         0      4560          19648           19648
# 1         1      4560          19648           19648
# 2         2      4560          19648           19648
# 3         3      4560          19648           19648
# 4         4      4560          19648           19648
# ...     ...       ...            ...             ...
# 2194   2222      4560          19648           19648
# 2195   2223      4560          19648           19648
# 2196   2224      4560          19648           19648
# 2197   2225      4560          19648           19648
# 2198   2226      4560          19648           19648
#
#       direction(front-0/left-1/right-2)
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# ...

# %%
df.count()
# Out:
# ImagePath    2199
# Angle        2199
# dtype: int64

# %%
df_csv.count()
# Out:
# index                                2199
# steering                             2199
# throttle_left                        2199
# throttle_right                       2199
# direction(front-0/left-1/right-2)    2199
# dtype: int64

# %%
df["ImagePath"][2198]
# Out:
# '/content/drive/MyDrive/Colab Notebooks/data3_value/frames/frame_536_6432.jpg'

# %%
df['index'] = df["ImagePath"].str.split("_")

# %%
df['index1'] = df['index'].str[2]

# %%
df['index1'] = pd.to_numeric(df['index'].str[2], downcast="integer")

# %%
df['index1']
# Out:
# 0       1341
# 1        143
# 2       1745
# 3       1777
# 4         43
#         ...
# 2194    2029
# 2195    1887
# 2196      23
# 2197     848
# 2198     536
# Name: index1, Length: 2199, dtype: int16

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   index                              2199 non-null   int64
#  1   steering                           2199 non-null   int64
#  2   throttle_left                      2199 non-null   int64
#  3   throttle_right                     2199 non-null   int64
#  4   direction(front-0/left-1/right-2)  2199 non-null   int64
# dtypes: int64(5)
# memory usage: 86.0 KB

# %%
df_csv
# Out:
#       index  steering  throttle_left  throttle_right  \
# 0         0      4560          19648           19648
# 1         1      4560          19648           19648
# 2         2      4560          19648           19648
# 3         3      4560          19648           19648
# 4         4      4560          19648           19648
# ...     ...       ...            ...             ...
# 2194   2222      4560          19648           19648
# 2195   2223      4560          19648           19648
# 2196   2224      4560          19648           19648
# 2197   2225      4560          19648           19648
# 2198   2226      4560          19648           19648
#
#       direction(front-0/left-1/right-2)
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ImagePath  2199 non-null   object
#  1   Angle      2199 non-null   int64
#  2   index      2199 non-null   object
#  3   index1     2199 non-null   int16
# dtypes: int16(1), int64(1), object(2)
# memory usage: 56.0+ KB

# %%
df.drop(columns="index", inplace=True)

# %%
df["index"] = df["index1"]
df.drop(columns="index1", inplace=True)

# %%
#result = pd.merge(left, right, on="key")
df_merged = pd.merge(df_csv, df, on="index")
df_merged
# Out:
#       index  steering  throttle_left  throttle_right  \
# 0         0      4560          19648           19648
# 1         1      4560          19648           19648
# 2         2      4560          19648           19648
# 3         3      4560          19648           19648
# 4         4      4560          19648           19648
# ...     ...       ...            ...             ...
# 2194   2222      4560          19648           19648
# 2195   2223      4560          19648           19648
# 2196   2224      4560          19648           19648
# 2197   2225      4560          19648           19648
# 2198   2226      4560          19648           19648
#
#       direction(front-0/left-1/right-2)  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# ...

# %%
labels = df_merged[["ImagePath", "direction(front-0/left-1/right-2)"]]
labels
# Out:
#                                               ImagePath  \
# 0     /content/drive/MyDrive/Colab Notebooks/data3_v...
# 1     /content/drive/MyDrive/Colab Notebooks/data3_v...
# 2     /content/drive/MyDrive/Colab Notebooks/data3_v...
# 3     /content/drive/MyDrive/Colab Notebooks/data3_v...
# 4     /content/drive/MyDrive/Colab Notebooks/data3_v...
# ...                                                 ...
# 2194  /content/drive/MyDrive/Colab Notebooks/data3_v...
# 2195  /content/drive/MyDrive/Colab Notebooks/data3_v...
# 2196  /content/drive/MyDrive/Colab Notebooks/data3_v...
# 2197  /content/drive/MyDrive/Colab Notebooks/data3_v...
# 2198  /content/drive/MyDrive/Colab Notebooks/data3_v...
#
#       direction(front-0/left-1/right-2)
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# ...

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
train_gen_flow = train_datagen.flow_from_dataframe(
        dataframe=labels,
        directory='/content/drive/MyDrive/Colab Notebooks/data3_value/frames/',
        x_col='ImagePath',
        y_col='direction(front-0/left-1/right-2)',
        target_size=(120, 160),
        batch_size=32,
        class_mode='raw',   #raw
        seed=12345)
# Out:
# Found 2199 validated image filenames.

# %%
features, target = next(train_gen_flow)
features.shape
# Out:
# (32, 120, 160, 3)

# %%
for i in range(5):
    plt.imshow(features[i])
    plt.title(target[i])
    plt.show()

# %%
def load_train(df):
    labels = df
    train_datagen = ImageDataGenerator(rescale=1/255.,
                                       # horizontal_flip=True,
                                       # width_shift_range=0.2,
                                        validation_split=0.25)

    train_datagen_flow = train_datagen.flow_from_dataframe(
        dataframe=labels,
        directory= '/content/drive/MyDrive/Colab Notebooks/data3_value/frames/',
        x_col='ImagePath',
        y_col='direction(front-0/left-1/right-2)',
        target_size=(120, 160),
        batch_size=32,
        class_mode='raw',
        subset='training',
        seed=12345)

    return train_datagen_flow

# %%
def load_test(df):
    labels = df
    test_datagen = ImageDataGenerator(rescale=1/255., validation_split=0.25)

    test_datagen_flow = test_datagen.flow_from_dataframe(
        dataframe=labels,
        directory= '/content/drive/MyDrive/Colab Notebooks/data3_value/frames/',
        x_col='ImagePath',
        y_col='direction(front-0/left-1/right-2)',
        target_size=(120, 160),
        batch_size=32,
        class_mode='raw',
        subset='validation',
        seed=12345)
    return test_datagen_flow

# %%
def create_model(input_shape): #120, 160, 3           480, 640
    backbone = ResNet50(input_shape=input_shape, weights='imagenet',
                        include_top=False)
    backbone.trainable = True
    model.add(backbone)
    model.add(GlobalAveragePooling2D())
    model.add(Dense(3, activation='softmax'))
    optimizer = Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy',
                  metrics=['acc'])
    return model

# %%
def train_model(model, train_data, test_data, batch_size=None,
                epochs=10, steps_per_epoch=None, validation_steps=None):

    if steps_per_epoch is None:
        steps_per_epoch = len(train_data)
    if validation_steps is None:
        validation_steps = len(test_data)
    model.fit(train_data, validation_data=test_data,
              batch_size=batch_size,
              epochs=epochs,
              steps_per_epoch=steps_per_epoch,
              validation_steps=validation_steps,
              verbose=2)
    return model

# %%
train = load_train(labels)
# Out:
# Found 1650 validated image filenames.

# %%
test = load_test(labels)
# Out:
# Found 549 validated image filenames.

# %%
model = create_model(input_shape=(120, 160, 3))

# %%
model_trained = train_model(model, train, test, batch_size=32)
# Out:
# Epoch 1/10
# 52/52 - 54s - loss: 0.1719 - acc: 0.9412 - val_loss: 2.5640 - val_acc: 0.0000e+00 - 54s/epoch - 1s/step
# Epoch 2/10
# 52/52 - 11s - loss: 0.0313 - acc: 0.9891 - val_loss: 3.9624 - val_acc: 0.3133 - 11s/epoch - 205ms/step
# Epoch 3/10
# 52/52 - 11s - loss: 0.0219 - acc: 0.9933 - val_loss: 4.7991 - val_acc: 0.3133 - 11s/epoch - 210ms/step
# Epoch 4/10
# 52/52 - 10s - loss: 0.0146 - acc: 0.9945 - val_loss: 6.0339 - val_acc: 0.3133 - 10s/epoch - 199ms/step
# Epoch 5/10
# 52/52 - 10s - loss: 0.0093 - acc: 0.9970 - val_loss: 6.8753 - val_acc: 0.3133 - 10s/epoch - 194ms/step
# Epoch 6/10
# 52/52 - 11s - loss: 0.0031 - acc: 0.9988 - val_loss: 6.5149 - val_acc: 0.3133 - 11s/epoch - 210ms/step
# Epoch 7/10
# 52/52 - 11s - loss: 8.8651e-04 - acc: 1.0000 - val_loss: 5.6218 - val_acc: 0.3133 - 11s/epoch - 209ms/step
# Epoch 8/10
# 52/52 - 10s - loss: 5.5338e-04 - acc: 1.0000 - val_loss: 4.9613 - val_acc: 0.3133 - 10s/epoch - 190ms/step
# Epoch 9/10
# ...

# %%
model_trained.history['val_acc']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-9347fa22a976> in <cell line: 1>()
# ----> 1 model_trained.history['val_acc']
#
# TypeError: 'History' object is not subscriptable
