# %%
import pandas as pd
import numpy as np

# %%
5+5
# Out:
# 10

# %%
data = pd.read_csv('/content/record.csv')

# %%
data.head()
# Out:
#     miliseconds  steering  throttle
# 0  1.697213e+09       0.2       0.3
# 1  1.697213e+09       0.2       0.3
# 2  1.697213e+09       0.2       0.3
# 3  1.697213e+09       0.2       0.3
# 4  1.697213e+09       0.2       0.3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4187 entries, 0 to 4186
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   miliseconds  4187 non-null   float64
#  1   steering     4187 non-null   float64
#  2   throttle     4187 non-null   float64
# dtypes: float64(3)
# memory usage: 98.3 KB

# %%
data
# Out:
#        miliseconds  steering  throttle
# 0     1.697213e+09      0.20       0.3
# 1     1.697213e+09      0.20       0.3
# 2     1.697213e+09      0.20       0.3
# 3     1.697213e+09      0.20       0.3
# 4     1.697213e+09      0.20       0.3
# ...            ...       ...       ...
# 4182  1.697213e+09     -0.55       0.3
# 4183  1.697213e+09     -0.55       0.3
# 4184  1.697213e+09     -0.55       0.3
# 4185  1.697213e+09     -0.55       0.3
# 4186  1.697213e+09     -0.55       0.3
#
# [4187 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.describe()
# Out:
#         miliseconds     steering  throttle
# count  4.187000e+03  4187.000000    4187.0
# mean   1.697213e+09    -0.342393       0.3
# std    9.172329e+00     0.335606       0.0
# min    1.697213e+09    -0.550000       0.3
# 25%    1.697213e+09    -0.550000       0.3
# 50%    1.697213e+09    -0.550000       0.3
# 75%    1.697213e+09     0.200000       0.3
# max    1.697213e+09     0.200000       0.3

# %%
data["steering"].value_counts()
# Out:
# -0.55    3028
#  0.20    1159
# Name: steering, dtype: int64

# %%
data["throttle"].value_counts()
# Out:
# 0.3    4187
# Name: throttle, dtype: int64
